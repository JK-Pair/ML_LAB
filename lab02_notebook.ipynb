# %% [markdown]
# # 2 Sentiment Analysis
# ## 2.2 Movie Review Data
#
# Let us first start by looking at the data provided with the exercise. We have positive and negative movie reviews labeled by human readers, all positive and negative reviews are in the ‘pos’ and ‘neg’ folders respectively. If you look in- side a sample file, you will see that these review messages have been ‘tokenized’, where all words are separated from punctuations.
# There are approximately 1000 files in each category with files names starting with cv000, cv001, cv002 and so on. You will split the dataset into training set and testing set.
#
# 1. Write some code to load the data from text files.

# %%
import pandas as pd
import numpy  as np
import os

# %%
neg_path = "txt_sentoken/neg"
neg = os.listdir(neg_path) #open text files in the neg file.
neg_dict = dict()
# read and origanize raw data in neg file.
for i in range(1000):
    neg_files = open("{}/{}".format(neg_path,neg[i]),"r")
    neg_word = neg_files.read().split(" ")
    
    for word in neg_word:
        if word in neg_dict:
            neg_dict[word] += 1
        else:
            neg_dict[word] = 1
            
# print(neg_dict)
# Out:
# {'plot': 855, ':': 1540, 'two': 832, 'teen': 74, 'couples': 14, 'go': 519, 'to': 15171, 'a': 17409, 'church': 25, 'party': 89, ',': 35269, 'drink': 17, 'and': 14700, 'then': 634, 'drive': 57, '.': 32162, '\nthey': 353, 'get': 1015, 'into': 1255, 'an': 2635, 'accident': 37, '\none': 201, 'of': 15287, 'the': 31275, 'guys': 150, 'dies': 49, 'but': 3266, 'his': 3761, 'girlfriend': 104, 'continues': 30, 'see': 746, 'him': 1153, 'in': 9270, 'her': 1976, 'life': 480, 'has': 2149, 'nightmares': 15, "\nwhat's": 40, 'deal': 87, '?': 2201, '\nwatch': 11, 'movie': 3035, '"': 9120, 'sorta': 4, 'find': 360, 'out': 1733, '\ncritique': 28, 'mind-fuck': 2, 'for': 4431, 'generation': 43, 'that': 7179, 'touches': 15, 'on': 3483, 'very': 724, 'cool': 113, 'idea': 212, 'presents': 27, 'it': 5051, 'bad': 1004, 'package': 15, '\nwhich': 34, 'is': 11043, 'what': 1241, 'makes': 430, 'this': 4150, 'review': 150, 'even': 1190, 'harder': 15, 'one': 2410, 'write': 75, 'since': 327, 'i': 2935, 'generally': 44, 'applaud': 3, 'films': 635, 'which': 1380, 'attempt': 171, 'break': 71, 'mold': 10, 'mess': 126, 'with': 4777, 'your': 402, 'head': 174, 'such': 542, '(': 5650, 'lost': 210, 'highway': 14, '&': 104, 'memento': 2, ')': 5742, 'there': 1014, 'are': 3208, 'good': 1112, 'ways': 78, 'making': 242, 'all': 2003, 'types': 18, 'these': 509, 'folks': 43, 'just': 1487, "didn't": 324, 'snag': 1, 'correctly': 9, 'seem': 271, 'have': 2640, 'taken': 98, 'pretty': 283, 'neat': 18, 'concept': 45, 'executed': 26, 'terribly': 41, '\nso': 274, 'problems': 154, '\nwell': 158, 'its': 968, 'main': 195, 'problem': 231, "it's": 1165, 'simply': 217, 'too': 770, 'jumbled': 10, '\nit': 826, 'starts': 153, 'off': 783, 'normal': 29, 'downshifts': 2, 'fantasy': 36, 'world': 339, 'you': 2024, 'as': 4482, 'audience': 452, 'member': 60, 'no': 1243, "what's": 104, 'going': 453, '\nthere': 427, 'dreams': 50, 'characters': 853, 'coming': 125, 'back': 465, 'from': 2203, 'dead': 181, 'others': 89, 'who': 2424, 'look': 413, 'like': 1762, 'strange': 75, 'apparitions': 3, 'disappearances': 2, 'looooot': 1, 'chase': 82, 'scenes': 619, 'tons': 8, 'weird': 46, 'things': 378, 'happen': 116, 'most': 816, 'not': 2431, 'explained': 46, '\nnow': 167, 'personally': 15, "don't": 615, 'mind': 164, 'trying': 313, 'unravel': 1, 'film': 3990, 'every': 448, 'now': 312, 'when': 1254, 'does': 680, 'give': 303, 'me': 745, 'same': 395, 'clue': 28, 'over': 619, 'again': 309, 'kind': 268, 'fed': 10, 'up': 1561, 'after': 640, 'while': 504, "film's": 257, 'biggest': 74, "\nit's": 648, 'obviously': 104, 'got': 274, 'big': 524, 'secret': 78, 'hide': 27, 'seems': 499, 'want': 291, 'completely': 227, 'until': 173, 'final': 151, 'five': 131, 'minutes': 382, '\nand': 868, 'do': 989, 'they': 1807, 'make': 810, 'entertaining': 126, 'thrilling': 10, 'or': 1537, 'engaging': 31, 'meantime': 12, '\nnot': 193, 'really': 770, '\nthe': 3596, 'sad': 53, 'part': 322, 'arrow': 12, 'both': 290, 'dig': 11, 'flicks': 37, 'so': 1635, 'we': 904, 'actually': 402, 'figured': 16, 'by': 2669, 'half-way': 3, 'point': 369, 'strangeness': 4, 'did': 402, 'start': 162, 'little': 701, 'bit': 241, 'sense': 230, 'still': 413, 'more': 1479, '\ni': 1100, 'guess': 145, 'bottom': 36, 'line': 199, 'movies': 544, 'should': 488, 'always': 213, 'sure': 212, 'before': 460, 'given': 270, 'password': 1, 'enter': 15, 'understanding': 14, 'mean': 119, 'showing': 72, 'melissa': 8, 'sagemiller': 8, 'running': 172, 'away': 311, 'visions': 14, 'about': 1789, '20': 37, 'throughout': 91, 'plain': 47, 'lazy': 22, '!': 1056, '\nokay': 25, '\nare': 24, 'people': 636, 'chasing': 17, 'know': 635, '\ndo': 32, 'need': 165, '\nhow': 100, 'giving': 106, 'us': 482, 'different': 144, 'offering': 11, 'further': 61, 'insight': 28, 'down': 427, '\napparently': 36, 'studio': 89, 'took': 72, 'director': 483, 'chopped': 3, 'themselves': 116, 'shows': 167, "might've": 9, 'been': 1065, 'decent': 102, 'here': 523, 'somewhere': 71, 'suits': 25, 'decided': 63, 'turning': 40, 'music': 192,  ...

# %%
pos_path = "txt_sentoken/pos"
pos = os.listdir(pos_path) #open text files in the pos file.
pos_dict = dict()
# read and origanize raw data in pos file.

for i in range(1000):
    pos_files = open("{}/{}".format(pos_path,pos[i]),"r")
    pos_word = pos_files.read().split(" ")
    
    for word in pos_word:
        if word in pos_dict:
            pos_dict[word] += 1
        else:
            pos_dict[word] = 1

# %%
pos_path = "txt_sentoken/pos"
neg_path = "txt_sentoken/neg"
neg = os.listdir(neg_path) #open text files in the neg file.
pos = os.listdir(pos_path) #open text files in the pos file.

# test_  = 
# train_ = 
pos_files = open("{}/{}".format(pos_path,pos[0]),"r")
neg_files = open("{}/{}".format(neg_path,neg[0]),"r")

# read and origanize raw data in pos file.
count = 0
pos_word = pos_files.read().split(" ")
neg_word = neg.files.read().split(" ")
for i in range(len(pos_word)):
    if pos_word[i] == 'from':
        count += 1
print(count)
# Out:
# 8

# %% [markdown]
# ## 2.3 TF-IDF
# From a raw text review, you want to create a vector, whose elements indicate the number of each word in each document. The frequency of all words within the documents are the ‘features’ of this machine learning problem.
#
# A popular method for transforming a text to a vector is called tf-idf, short for term frequencyinverse document frequency.
#
# 1. Conduct a research about tf-idf and explain how it works.
# 2. Scikit-learn provides a module for calculating this, this is called TfidfVec- torizer.
# You can study how this function is used here:
#
# `http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html`
#
# Write code to transform your text to tf-idf vector.

# %% [markdown]
# ## Ans 2.3.1  TF-IDF
#
# TF-IDF มาจากคำว่า Normalized term frequency กับคำว่า Inverse Documents frequency
# TF-IDF คือ weight ของจำนวนคำที่อยู่ใน data ที่เป็น text โดยที่ term frequence คือความถี่ของคำนั้นๆที่อยู่ document และ Inverse Documents frequency คือ ความสำคัญของคำนั้นๆ ถ้าเจอคำนั้นๆใน document น้อยแสดงว่ามีความสำคัญมาก
#
# วิธีการทำงานของ TF-IDF คือความถี่ของคำนั้นๆคูณกับความสำคัญของคำนั้นๆ

# %% [markdown]
# ## 2.4 Classification
#
# Use 4 different models to classify each movie into positive or negative category.
#
# 1. K-Nearestneighbormodel,using module `sklearn.neighbors.KNeighborsClassifier`
# 2. RandomForest, using module `sklearn.ensemble.RandomForestClassifier`
# 3. SVM, using module `sklearn.svm.SVC`
# 4. Neural network, using `sklearn.neural_network.MLPClassifier`
#
# You may pick other models you would like to try. Just present results for at least 4 models.
# Please provide your code for model fitting and cross validation. Calculate your classification accuracy, precision, and recall.

# %% [markdown]
# ## 2.5 Model Tuning
#
# Can you try to beat the simple model you created above? Here are some things you may try:
#
# * When creating TfidfVectorizer object, you may tweak sublinear_tf parameter which use the tf with logarithmic scale instead of the usual tf.
# * You may also exclude words that are too frequent or too rare, by adjusting max_df and min_df.
# * Adjusting parameters available in the model, like neural network structure or number of trees in the forest.
#
# Design at least 3 experiments using these techniques. Show your experimental results.

# %% [markdown]
# # 3 Text Clustering
# We have heard about Google News clustering. In this exercise, we are going to implement it with Python.
#
# ## 3.1 Data Preprocessing
# Let’s switch up and use another dataset called 20newsgroup data, which is a collection of approximately 20,000 newsgroup documents, partitioned (nearly) evenly across 20 different newsgroups. The data is collected from a university’s mailing list, where students exchange opinions in everything from motorcycles to middle east politics.
#
# 1. Import data using sklearn.datasets.fetch_20newsgroups
# 2. Transform data to vector with TfidfVectorizer

# %% [markdown]
# ## 3.2 Clustering
# We are going to use the simplest clustering model, k-means clustering, to do this task. Our hope is that this simple algorithm will result in meaningful news categories, without using labels.
#
# 1. Fit K-Means clustering model to the text vector. What is the value of K you should pick? Why?
# 2. Use Silhouette score to evaluate your clusters. Try to evaluate the model for different values of k to see which k fits best for the dataset.

# %% [markdown]
# # 3.3 Topic Terms
# We want to explore each cluster to understand what news articles are in the cluster, what terms are associated with the cluster. This will require a bit of hacking.
# 1. Use TfidfVectorizer.get feature names to extract words associated with each dimension of the text vector.
# 2. Extract cluster’s centroids using kmeans.cluster centers .
# 3. For each centroid, print the top 15 words that have the highest frequency.
